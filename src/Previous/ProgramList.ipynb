// %%
CoreJavaProgramming.
WAP to find enter number is odd or even number
WAP to find enter number is prime number
WAP to find prime number in a given series
WAP to reverse a given number
WAP to find pallindrome number
WAP to find sum of digits of number
WAP to find armstrong number
WAP to swap values of 2 number using 3rd vriable
WAP to swap values of 2 number without using 3rd vriable
WAP to print fibonacci series
WAP a program to print non void method value

WAP to print without writing SOP - pending
WAP to find anagram  - Pending

String
WAP to reverse string, I/p (Anurag is an engineer) O/p (reenigne na si garunA)
WAP to reverse string words position, (I/p Cat Rat Mat Sat) O/p (Sat Mat Rat Cat)
WAP to find Pallindrome via string input a. using only string b. using StringBuilder
WAP to find occurence of characters in a given string
WAP to break the  string as per white space and print the separated string - String s = "My Name Is Anurag"
WAP to print o/p- 1*2**3***4****
WAP to print o/p- 1*2**3****4********




Collection
WAP to count element with prefix a or A
WAP to print all the elements of array list
WAP to print all the elements of array list having length>4
WAP to print 1 element of array list having length>4
WAP to convert arrays to arraylist
WAP to verify specific element present in list or not

Stream
WAP to count element with prefix a or A
WAP to print all the elements of array list using streams
WAP to print all the elements of array list having length>4 using streams
WAP to print 1 element of array list having length>4 using streams
WAP to convert all list elements to uppercase and print
WAP to print list elements which ends with "a" in uppercase
WAP to print elements starting with a in uppercase and sorted order
WAP to combine 2 list of elements
WAP to verify specific element present in list or not
WAP to print elements starting with a in uppercase, store in new list and fetch 1st element of new list
WAP to print unique number in integer array and sort it
WAP to create a new list, sort it and fetch 3rd index element from array

Array
WAP to sort array
WAP to Find smallest no. in array
WAP to Find largest no. in array
WAP to Find 2nd largest no. in array
WAP to print unique element in array
WAP to find occurence of element in duplicate array
WAP to sum of elements of arrays
Wap to sum of odd and sum of even elements in array
WAP to find mean of array
WAP to verify specific element present in array
